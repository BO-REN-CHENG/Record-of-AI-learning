# %% [markdown]
# # 3/5 PYTHON 練習14 Python 網路連線程式、公開資料串接
# * [Python 網路連線程式、公開資料串接 By 彭彭](https://www.youtube.com/watch?v=sUzR3QVBKIo&list=PL-g0fdC5RMboYEyt6QS2iLb_1m7QcgfHk&index=15)

# %% [markdown]
# # 網路連線

# %%
import urllib.request as request
src="http://www.ntu.edu.tw/" 
with request.urlopen(src) as response:
    data=response.read()#取得台灣大學原始碼(HTML,CSS,JS)
print(data)
# Out:
# b' <html lang="zh-tw" xmlns:og="http://ogp.me/ns#">\n<!--<![endif]-->\n<head>\n\n<link rel="apple-touch-icon" href="images/appletouch.gif" />\n<link rel="SHORTCUT ICON" href="images/faviconntu.ico" />\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no">\n<meta property="og:title" content="\xe5\x9c\x8b\xe7\xab\x8b\xe8\x87\xba\xe7\x81\xa3\xe5\xa4\xa7\xe5\xad\xb8">\n<meta property="og:site_name" content="\xe5\x9c\x8b\xe7\xab\x8b\xe8\x87\xba\xe7\x81\xa3\xe5\xa4\xa7\xe5\xad\xb8">\n<meta property="og:description" content="\xe
# ...

# %%
import urllib.request as request
src="http://www.ntu.edu.tw/" 
with request.urlopen(src) as response:
    data=response.read().decode("utf-8")#取得台灣大學原始碼 解讀中文部分(HTML,CSS,JS)
print(data)
# Out:
#  <html lang="zh-tw" xmlns:og="http://ogp.me/ns#">
# <!--<![endif]-->
# <head>
#
# <link rel="apple-touch-icon" href="images/appletouch.gif" />
# <link rel="SHORTCUT ICON" href="images/faviconntu.ico" />
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no">
# <meta property="og:title" content="國立臺灣大學">
# <meta property="og:site_name" content="國立臺灣大學">
# <meta property="og:description" content="臺灣第一所最完整，歷史最悠久，且最具代表之綜合性高等教育學府">
# <meta property="og:url" content="https://www.ntu.edu.tw/">
# <meta property="og:image" content="https://www.ntu.edu.tw/images/photo/ntugate.jpg">
# <meta http-equiv="Pragma" content="no_cache">
# <script src="js/libs/jquery-1.10.2.min.js"></script>
# <link rel="canonical" href=" "/>
# <!--[if lt IE 7 ]>
# <meta content="0; url=ie6.html" http-equiv="refresh" />
#         <![endif]-->
# ...

# %% [markdown]
# # 串接截取公開資料

# %%
import urllib.request as request
import json
src="http://117.56.59.17/OpenData/API/Rain/Get?stationNo=&loginId=open_rain&dataKey=85452C1D"
with request.urlopen(src) as response:
     data=json.load(response) #利用json模組處理 json資料格式
print(data)
# Out:
# {'count': 166, 'data': [{'stationNo': 'C0AD1', 'stationName': '八里', 'recTime': '202003051940', 'rain': 14.5}, {'stationNo': 'C0AD0', 'stationName': '三芝', 'recTime': '202003051940', 'rain': 24.0}, {'stationNo': 'C0AD4', 'stationName': '土城', 'recTime': '202003051940', 'rain': 16.0}, {'stationNo': '318', 'stationName': '大安福州山', 'recTime': '202003051902', 'rain': 17.5}, {'stationNo': '01A17', 'stationName': '坪林', 'recTime': '201911130140', 'rain': 0.0}, {'stationNo': 'C0AD2', 'stationName': '深坑', 'recTime': '', 'rain': 0.0}, {'stationNo': 'C0AD3', 'stationName': '蘆洲', 'recTime': '202003051940', 'rain': 14.5}, {'stationNo': 'C0AD5', 'stationName': '鶯歌', 'recTime': '202003051940', 'rain': 13.5}, {'stationNo': '01A21', 'stationName': '大豹', 'recTime': '202003051940', 'rain': 17.0}, {'stationNo': '125', 'stationName': '中正橋', 'recTime': '202003051930', 'rain': 15.0}, {'stationNo': '01A43', 'stationName': '福山', 'recTime': '202003051940', 'rain': 15.0}, {'stationNo': '01A44', 'stationName': '大桶山
# ...

# %% [markdown]
# ### 取得觀測站名稱

# %%
import urllib.request as request
import json
src="http://117.56.59.17/OpenData/API/Rain/Get?stationNo=&loginId=open_rain&dataKey=85452C1D"
with request.urlopen(src) as response:
    data=json.load(response) #利用json模組讀取資料
#取得觀測站名稱, 並寫入檔案(weather.txt)
slist=data["data"]
print(slist)
print("\n--------------------------------------------------------------------------------------------------\n")
for no in slist:    #no為隨意命名變數
    print(no["stationNo"])
with open("weather.txt","w", encoding="utf=8") as file:
    for name in slist:
        file.write(name["stationName"]+"\n")
# Out:
# [{'stationNo': 'C0AD1', 'stationName': '八里', 'recTime': '202003052000', 'rain': 14.5}, {'stationNo': 'C0AD0', 'stationName': '三芝', 'recTime': '202003052000', 'rain': 24.0}, {'stationNo': 'C0AD4', 'stationName': '土城', 'recTime': '202003052000', 'rain': 16.0}, {'stationNo': '318', 'stationName': '大安福州山', 'recTime': '202003052002', 'rain': 17.5}, {'stationNo': '01A17', 'stationName': '坪林', 'recTime': '201911130140', 'rain': 0.0}, {'stationNo': 'C0AD2', 'stationName': '深坑', 'recTime': '', 'rain': 0.0}, {'stationNo': 'C0AD3', 'stationName': '蘆洲', 'recTime': '202003052000', 'rain': 14.5}, {'stationNo': 'C0AD5', 'stationName': '鶯歌', 'recTime': '202003052000', 'rain': 13.5}, {'stationNo': '01A21', 'stationName': '大豹', 'recTime': '202003052000', 'rain': 17.0}, {'stationNo': '125', 'stationName': '中正橋', 'recTime': '202003051950', 'rain': 15.0}, {'stationNo': '01A43', 'stationName': '福山', 'recTime': '202003052000', 'rain': 15.0}, {'stationNo': '01A44', 'stationName': '大桶山', 'recTime': '20200305
# ...
