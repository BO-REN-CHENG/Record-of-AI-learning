# %% [markdown]
# # 3/10 PYTHON 練習19 Python 網路爬蟲 Web Crawler 教學 - Cookie 操作實務
# * [Python 網路爬蟲 Web Crawler 教學 - Cookie 操作實務 By 彭彭](https://www.youtube.com/watch?v=BEA7F9ExiPY&list=PL-g0fdC5RMboYEyt6QS2iLb_1m7QcgfHk&index=20)

# %% [markdown]
# # 抓取ptt八卦版的網頁原始碼
# * 會失敗 因為八卦版多了需要按已滿18歲 按了後記錄在cookie

# %%
import urllib.request as req
url="https://www.ptt.cc/bbs/Gossiping/index.html"
#建立一個request物件,附加request headers的資訊
request=req.Request(url,headers={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.132 Safari/537.36"
})
with req.urlopen(request) as response:
    data=response.read().decode("utf-8")
import bs4
root=bs4.BeautifulSoup(data,"html.parser")#讓beautifulsoup協助我們解析HTML格式文件
titles=root.find_all("div",{"class":"title"})#尋找 class="title"的div標籤
for  title in titles:
    if title.a!=None:#如果標題包含a標籤(沒有被刪除),印出來
        print(title.a.string)
#失敗!

# %%
import urllib.request as req
def getData(url):
#建立一個request物件,附加request headers的資訊
    request=req.Request(url,headers={
        "cookie":"over18=1",
        "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.132 Safari/537.36"
    })
    with req.urlopen(request) as response:
        data=response.read().decode("utf-8")
    import bs4
    root=bs4.BeautifulSoup(data,"html.parser")#讓beautifulsoup協助我們解析HTML格式文件
    titles=root.find_all("div",{"class":"title"})#尋找 class="title"的div標籤
    for  title in titles:
        if title.a!=None:#如果標題包含a標籤(沒有被刪除),印出來
            print(title.a.string)
    #抓取上一頁的連結
    nextlink=root.find("a",string="‹ 上頁")#找到內文是‹ 上頁的a標籤
    #print(nextlink)
    #print(nextlink["href"])
    return nextlink["href"]
#抓取一個頁面的標題
pageURL="https://www.ptt.cc/bbs/Gossiping/index.html"
count=0
while count<=3:
    print("\n----------------------------\n")
    pageURL="https://www.ptt.cc"+getData(pageURL) 
    count+=1
#print(getData(pageURL))
# Out:
# ----------------------------
#
# [問卦] 女森說大鬍子親親像地毯一樣？
# [問卦] 我就問 中國開局這麼漂亮要怎麼才有辦法
# [新聞] 張柏芝遭爆飛機上起衝突 帶3小孩被趕下飛
# Re: [新聞] 連續8個月凌晨大喊「我愛你」 強制罪起訴
# Re: [新聞] 4月口罩站上可「防疫外交」門檻 給哪國
# Re: [新聞] 影／習近平深入武漢社區　隔離阿婆拉下
# [問卦] 為何不能要求女生要煮飯?
# [問卦] 聽高爾宣哪幾首歌最內行？
# Re: [新聞] 4月口罩站上可「防疫外交」門檻 給哪國
# [問卦] x1文有多難發
# Re: [問卦] 肥宅聊大麻有加分嗎
# [公告] 八卦板政治文規範草案開始討論
# [公告] 八卦板板規(2019.08.21)
# [公告] 三月份置底閒聊文
# [公告] 報名截止啦~~~
# [協尋] 急~親人走失，麻煩台北、新北鄉民幫忙協
#
# ----------------------------
#
# [新聞] 45歲大叔娶嫩妻！半夜聽見怪聲…揭20歲兒
# Re: [爆卦] 有沒有Google評論給一星就要提告的八卦
# [問卦] 驚! 小海女のん能年玲奈 在NHK晨間節目?
# [問卦] 台灣機場幾時才能下雨不漏水
# [問卦] 空姐現在是不是很閒的八卦?
# [問卦] 私人的本本會給別人看嗎？
# [問卦] 澳門是不是很悶
# [問卦] 中國有跟戈巴契夫同樣定位的領導者嗎
# [問卦] 有沒有Telegram是不是過譽的八卦？
# Re: [新聞] 美商會長籲川普買下台灣 蘇揆：我們不賣
# [新聞] 連續8個月凌晨大喊「我愛你」 強制罪起訴
# Re: [新聞] 六都唯獨北市托育補助還沒發 議員酸難怪
# [新聞] 「千年一遇空姐」側胸開洞超辣！高顏值美
# [新聞] 武肺疫情衝擊美股跳樓！川普推文安撫：流感嚴重多了
# Re: [問卦] 說同意台灣變美國的人 是真心還反串
# [問卦] 當兵期間怎麼看A片抒發？
# [問卦] 大家村裡廣播都放什麼音樂
# Re: [新聞] 口罩實名制2.0擬3方式網購 運費15元以內
# [新聞] 堅反國土計畫法修法 國民黨：政院提一次
# Re: [問卦] 日本樂壇在亞洲退燒原因？
#
# ...

# %% [markdown]
# # 自我練習 完整化

# %%
import urllib.request as req
n=int(input("請輸入想要找幾頁的八卦版標題: "))
'''''''''''
n=int(input("請輸入想要找幾頁的八卦版標題: "))為下方兩個的縮寫
n=input("請輸入想要找幾頁的八卦版標題: ")
n=int(n)
'''''''''''
def getData(url):
#建立一個request物件,附加request headers的資訊
    request=req.Request(url,headers={
        "cookie":"over18=1",
        "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.132 Safari/537.36"
    })
    with req.urlopen(request) as response:
        data=response.read().decode("utf-8")
    import bs4
    root=bs4.BeautifulSoup(data,"html.parser")#讓beautifulsoup協助我們解析HTML格式文件
    titles=root.find_all("div",{"class":"title"})#尋找 class="title"的div標籤
    for  title in titles:
        if title.a!=None:#如果標題包含a標籤(沒有被刪除),印出來
            print(title.a.string)
    #抓取上一頁的連結
    nextlink=root.find("a",string="‹ 上頁")#找到內文是‹ 上頁的a標籤
    #print(nextlink)
    #print(nextlink["href"])
    return nextlink["href"]
#抓取一個頁面的標題
pageURL="https://www.ptt.cc/bbs/Gossiping/index.html"
count=0
while count<n:
    print("\n---------------","page",count+1,"-------------------\n")
    pageURL="https://www.ptt.cc"+getData(pageURL) 
    count+=1
#print(getData(pageURL))
# Out:
# 請輸入想要找幾頁的八卦版標題: 3
#
# --------------- page 1 -------------------
#
# [問卦] 華人最有可能得諾貝爾經濟學獎的人是誰？
# Re: [新聞] 4月口罩站上可「防疫外交」門檻 給哪國
# [問卦] 蛇丸是不是屌虐整個NSFW
# Re: [問卦] 為什麼威士忌的味道可以說到飛天鑽地
# [問卦] 有沒有很弱的病毒？
# Re: [問卦] 為啥美國二次大戰沒把台灣給占領了?
# [爆卦] 台灣製的南韓口罩地圖上線
# [問卦] 內褲哪一牌比較好穿啊
# Re: [問卦] 驚!!姊姊意外事故變電腦了??
# [新聞] 武漢肺炎》第二批專機幕後...確認「橫濱
# [問卦] 醫生如果被台人跪舔 要怎麼表現?
# [問卦] 唸 大乘(ㄕㄥˋ)佛教 還是大乘(ㄔㄥˊ)?
# [公告] 八卦板政治文規範草案開始討論
# [公告] 八卦板板規(2019.08.21)
# [公告] 三月份置底閒聊文
# [公告] 報名截止啦~~~
# [協尋] 急~親人走失，麻煩台北、新北鄉民幫忙協
#
# --------------- page 2 -------------------
#
# [問卦] 女森說大鬍子親親像地毯一樣？
# [問卦] 我就問 中國開局這麼漂亮要怎麼才有辦法
# [新聞] 張柏芝遭爆飛機上起衝突 帶3小孩被趕下飛
# Re: [新聞] 連續8個月凌晨大喊「我愛你」 強制罪起訴
# Re: [新聞] 4月口罩站上可「防疫外交」門檻 給哪國
# Re: [新聞] 影／習近平深入武漢社區　隔離阿婆拉下
# [問卦] 為何不能要求女生要煮飯?
# [問卦] 聽高爾宣哪幾首歌最內行？
# Re: [新聞] 4月口罩站上可「防疫外交」門檻 給哪國
# [問卦] x1文有多難發
# Re: [問卦] 肥宅聊大麻有加分嗎
# [問卦] 有沒有嘉義學生都騎車上下學的掛
# [問卦] 家裡有超級崇尚中國的人怎辦
# [問卦] 鐘錶行老闆娘會幫忙破案
# Re: [新聞] 大三決定不當老師 刪臉書、IG...她應屆
# [問卦] 18個人想搭包機但是拒檢是什麼概念？
# [問卦] 驚!!姊姊意外事故變電腦了??
# [問卦] 104 v.s. linkedin
# [新聞] 信義區違規迴轉被開單　男告上法院：我4
# ...
